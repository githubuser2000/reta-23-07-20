# %%
from ansi2html import Ansi2HTMLConverter
import sys
sys.path.insert(1, '/home/alex/myRepos/reta')
import subprocess
from IPython.core.display import HTML
# Erstellen Sie einen neuen Konverter mit Standardoptionen
converter = Ansi2HTMLConverter()

def externCommand(cmd: str, parameter: list[str]):
    #return subprocess.check_output([cmd, *parameter], stderr=subprocess.STDOUT, universal_newlines=True)
    p = subprocess.Popen([cmd, *parameter], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    output, err = p.communicate()
    return output

befehl = "a u e 1".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi4 { text-decoration: underline; }
# .ansi30 { color: #000316; }
# .ansi37 { color: #F5F1DE; }
# .ansi41 { background-color: #aa0000; }
# .ansi100 { background-color: #7f7f7f; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# 1
# ['absicht', 'universum', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '1']
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone,    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil              </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne</span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen</span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13)  </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">als Form des Geistes (15)                                                </span>
#  1 <span class="ansi100"></span><span class="ansi37 ansi100">„Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle    </span>
#    <span class="ansi100"></span><span class="ansi37 ansi100">Paradigmen haben: einen „Denkansatz“)                                    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Transzendentalien, -alien, universelle Strukturalien, Meta-Paradigmen    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">(15) Transzendentalien (15 oder u.a. 15) sind die menschliche Sicht der  </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Strukturalien (ausschließlich Typ 15) (In Lebewesen ist es Bewusstsein.).</span>
#  1 <span class="ansi100"></span><span class="ansi37 ansi100">Identität, z.B. mathematisch (1)                                         </span>
#
# </pre>
# </body>
#
# </html>

# %%
from IPython.display import HTML
import sys
sys.path.insert(1, '/home/alex/myRepos/reta')
import subprocess
from IPython.core.display import HTML
# Erstellen Sie einen neuen Konverter mit Standardoptionen

def externCommand(cmd: str, parameter: list[str]):
    #return subprocess.check_output([cmd, *parameter], stderr=subprocess.STDOUT, universal_newlines=True)
    p = subprocess.Popen([cmd, *parameter], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    output, err = p.communicate()
    return output

befehl = "a u e 1 -spalten --breite=0 -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
HTML(htmlAusgabe)
# Out:
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Inkrementieren,Inkrementieren,Universum,Universum,Universum,Wichtigstes_zum_verstehen, p2_p3_0_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_10_,p3_1_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_2_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_3_Transzendentalien,p3_4_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_5_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_6_Wichtigste,p3_7_,p3_8_,p3_9_, p4_0,4"> Transzendentalien, -alien, universelle Strukturalien, Meta-Paradigmen (15) Transzendentalien (15 oder u.a. 15) sind die menschliche Sicht der Strukturalien (ausschließlich Typ 15) (In Lebewesen ist es Bewusstsein.). </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> Identität, z.B. mathematisch (1) </td> </tr>
# </table>

# %%
befehl = "a v e 1/5-1/6,-1/10-1/12,-1/18,1/31-1/32 -spalten --breite=0 -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# ['absicht', 'vielfache', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '1/5-1/6,-1/10-1/12,-1/18,1/31-1/32', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> taugen, streben (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> einschätzen, bewerten, Klarheit oder Ethik wollen, gesellschaftliche Werte wollen (sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 15 </td> <td> Respekt in anderen sehen, sich durch andere selbst reflektieren wollen (d.h. umgekehrter Selbstrespekt) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#000099;color:#ffff66;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 25 </td> <td> für Freizeitangebote sorgen wollen; etwas für die Gesellschaft und Menschenmassen tun wollen (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 31 </td> <td> Konsumieren wollen von Feinsinniger Hochkultur, wie z.B. Oper (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 32 </td> <td> arrangieren und organisieren und auch verherrlichen (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 35 </td> <td> Ziel für Wohltätigkeiten und Philanthropie sein wollen, dessen gültig Gutes erhalten wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 42 </td> <td> stark gemacht werden wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 45 </td> <td> befruchtet werden wollen bzw. als Mann zu wollen, dass die Frau Aktion ergreift, dass sie befruchtet wird, während der Mann passiv ist, also eher wie bei künstlicher Befruchtung (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 62 </td> <td> Zu wollen, dass andere mit deiner Verletzlichkeit umgehen sollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 64 </td> <td> Jemanden mental sozusagen hinterher rennen (halb sicher); andere Menschen zu delegieren (halb sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 10 </td> <td> 78 </td> <td> Der Wunsch, gefördert zu werden (größtenteils sicher) </td> </tr>
# </table>

# %%
befehl = "a v e 1/5-1/6,-1/10-1/12,-1/18,1/31-1/32 -spalten --breite=0 -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# ['absicht', 'vielfache', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '1/5-1/6,-1/10-1/12,-1/18,1/31-1/32', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> taugen, streben (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> einschätzen, bewerten, Klarheit oder Ethik wollen, gesellschaftliche Werte wollen (sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 15 </td> <td> Respekt in anderen sehen, sich durch andere selbst reflektieren wollen (d.h. umgekehrter Selbstrespekt) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#000099;color:#ffff66;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 25 </td> <td> für Freizeitangebote sorgen wollen; etwas für die Gesellschaft und Menschenmassen tun wollen (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 31 </td> <td> Konsumieren wollen von Feinsinniger Hochkultur, wie z.B. Oper (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 32 </td> <td> arrangieren und organisieren und auch verherrlichen (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 35 </td> <td> Ziel für Wohltätigkeiten und Philanthropie sein wollen, dessen gültig Gutes erhalten wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 42 </td> <td> stark gemacht werden wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 45 </td> <td> befruchtet werden wollen bzw. als Mann zu wollen, dass die Frau Aktion ergreift, dass sie befruchtet wird, während der Mann passiv ist, also eher wie bei künstlicher Befruchtung (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 62 </td> <td> Zu wollen, dass andere mit deiner Verletzlichkeit umgehen sollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 64 </td> <td> Jemanden mental sozusagen hinterher rennen (halb sicher); andere Menschen zu delegieren (halb sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 10 </td> <td> 78 </td> <td> Der Wunsch, gefördert zu werden (größtenteils sicher) </td> </tr>
# </table>

# %%
def teste(orte: str) -> str:
    befehl = ("e "+orte+" -spalten --breite=0 -ausgabe --art=html --onetable").split()
    htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])
    return htmlAusgabe

# ausgabe war richtig: 11,12,14,15,22,24
# nein war nicht richtig, erst jetzt wurden die vielfacher von 1/11 und 1/12 gebildet
HTML(teste("u1/14-1/15,v1/11-1/12,-1/44-1/48"))
# Out:
# 14-15,v11-12,-44-48
# 14-15,v11-12,-44-48
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Universum,✗Grundstrukturen,✗Grundstrukturen,, p2_p3_0_Reziproke_von_Transzendentalien,p3_1_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_2_Reziprokes,p3_3_,p3_4_,p3_5_, p4_4,1"> Reziproke 1/n von „Transzendentalien bzw. Strukturalien“: Die Grundlage für Gleichförmiges-Polygon-Religionen (Reziproke sind Typ 15 und diese Strukturalien, von denen die Reziproke gebildet werden sind zudem auch Typ 15.) </td> <td class="z_0 r_3 p1_✗Universum,, p2_p3_0_Reziproke_von_Transzendentalien,p3_1_,p3_2_,p3_3_, p4_4,1"> Brucherweiterungen von: Reziproke 1/n von „Transzendentalien bzw. Strukturalien“: Die Grundlage für Gleichförmiges-Polygon-Religionen (Reziproke sind Typ 15 und diese Strukturalien, von denen die Reziproke gebildet werden sind zudem auch Typ 15.) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 11 </td> <td> 1/11 Merkmal, Spezifikum, Anhaltspunkt (größtenteils sicher) </td> <td> 2/22 alle einzelnen UML-Diagramm-Bestandteile (Softwareentwicklung) (nicht total sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 12 </td> <td> 1/12 „die Karte“ und damit „die Filterung“ (Filterung so intelligent wie Bilderverarbeitung mit Algorithmen) und auch „die Grundlage wonach sortiert wird“ (alles sicher); Gattung bzw. Art einer Einteilung (halb bis größtenteils sicher) , nur abstrakte - nie konkrete Universalien (Spekulation) Es ist die Invariante der Informatik-Container-Datenstrukur (12) oder auch der mathematischen Menge. (So wie 1/10 Ontologien beinhaltet, die auf Bedeutung [10] basieren, so hat 1/12 etwas vergleichbares komplexeres abstraktes, das auf der Wesenhaftigkeit und Komplexität selbst und dem Status [Impuls 12] [in einer Ordnung] basiert.); Software-Programmierung-Zeiger auf Container-Datenstrukturen und hier bei 1/12 die Frage, wo man diese positioniert </td> <td> 2/24 Knoten und Kanten eines Netzwerkes, ggf. Maschen (sehr sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> 1/14 die Analyse (größtenteils sicher) </td> <td> 2/28 Bestandteile des metrischen Raumes: Positive Definitheit, Symmetrie, Dreiecksungleichung (größtenteils sicher) und ggf. die einzelnen wenigen grundsätzlichen Bestandteile (d.h. die Teile der mathematischen Definition) von Topologien (1/14 Analyse stimmt wahrscheinlich, 2/28 könnte stimmen) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 15 </td> <td> 1/15 Extraversion (bin mir halb sicher);mathematisch: die Schleifeninvariante, die Invariante einer Rekursion und einer Traversierung (sicher) </td> <td> 2/30 die nur wesentlichen Bestandteile aus denen Fasern und Bündel von Topologien bestehen (könnte stimmen) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 22 </td> <td> Metadiversitäten könnte man das nennen: Vererbungsgrundlagen, warum wie und warum vererbt wird, z.B. Evolution oder mendelsche Regeln oder was die Programmiersprache zur Vererbung ermöglicht, oder der Teil der Wissenschaftlichen Methodik, der bewirkte, dass neuere Forschungen älterer Forschung widersprechen (weil Forschungsbaum: also Vererbung) (größtenteils sicher) </td> <td> ? </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 24 </td> <td> Die Klärung, das Klar-machen, das Transparent machen, die Störungs-Verwaltung, das Netzwerkprotokoll (größtenteils sicher) Es ist die Invariante des Netzwerkes (24). (größtenteils sicher) </td> <td> ? </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 33 </td> <td> Automatisierungsprinzipien oder Automatisierungsgrundlagen (halb bis größtenteils sicher); regelkonforme bzw. regelerhaltende, kovariante Übersetzungs-Gestaltung, also nicht die Übersetzung selbst, sondern nach welchen Grundsätzen diese vonstatten geht (halb bis größtenteils sicher) </td> <td> ? </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 36 </td> <td> Datenbankanalyse, Datenbank Rückbetrachtung, Daten, die es zu managen gilt (größtenteils sicher) </td> <td> ? </td> </tr>
# </table>

# %%
HTML(teste("v u 1/14-1/15,v1/11-1/12,-1/44-1/48"))
# Out:
# 14,28,42,56,70,84,98,112,126,140,154,168,182,196,210,224,238,252,266,280,294,350,364,378,392,406,420,434,448,462,476,490,504,518,532,546,560,574,588,602,686,700,714,728,742,756,770,784,798,812,826,840,854,868,882,896,910,938,952,980,994,1022,15,30,60,75,105,120,150,165,195,255,285,300,330,345,375,390,435,465,510,525,555,570,600,615,645,735,750,780,795,825,870,885,915,930,975,1005,1020,11,22,33,55,66,77,99,110,121,143,187,198,209,231,242,253,275,286,297,319,341,363,374,385,407,418,429,451,473,539,550,561,583,594,605,627,638,649,671,682,693,715,726,737,759,781,803,814,847,858,869,891,902,913,935,946,957,979,1001,1023,12,24,36,72,108,156,204,216,228,312,324,348,372,408,444,456,468,492,516,612,636,648,684,696,708,732,744,804,852,876,888,936,948,972,984,996
# 14,28,42,56,70,84,98,112,126,140,154,168,182,196,210,224,238,252,266,280,294,350,364,378,392,406,420,434,448,462,476,490,504,518,532,546,560,574,588,602,686,700,714,728,742,756,770,784,798,812,826,840,854,868,882,896,910,938,952,980,994,1022,15,30,60,75,105,120,150,165,195,255,285,300,330,345,375,390,435,465,510,525,555,570,600,615,645,735,750,780,795,825,870,885,915,930,975,1005,1020,11,22,33,55,66,77,99,110,121,143,187,198,209,231,242,253,275,286,297,319,341,363,374,385,407,418,429,451,473,539,550,561,583,594,605,627,638,649,671,682,693,715,726,737,759,781,803,814,847,858,869,891,902,913,935,946,957,979,1001,1023,12,24,36,72,108,156,204,216,228,312,324,348,372,408,444,456,468,492,516,612,636,648,684,696,708,732,744,804,852,876,888,936,948,972,984,996
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Universum,✗Grundstrukturen,✗Grundstrukturen,, p2_p3_0_Reziproke_von_Transzendentalien,p3_1_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_2_Reziprokes,p3_3_,p3_4_,p3_5_, p4_4,1"> Reziproke 1/n von „Transzendentalien bzw. Strukturalien“: Die Grundlage für Gleichförmiges-Polygon-Religionen (Reziproke sind Typ 15 und diese Strukturalien, von denen die Reziproke gebildet werden sind zudem auch Typ 15.) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 11 </td> <td> 1/11 Merkmal, Spezifikum, Anhaltspunkt (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 12 </td> <td> 1/12 „die Karte“ und damit „die Filterung“ (Filterung so intelligent wie Bilderverarbeitung mit Algorithmen) und auch „die Grundlage wonach sortiert wird“ (alles sicher); Gattung bzw. Art einer Einteilung (halb bis größtenteils sicher) , nur abstrakte - nie konkrete Universalien (Spekulation) Es ist die Invariante der Informatik-Container-Datenstrukur (12) oder auch der mathematischen Menge. (So wie 1/10 Ontologien beinhaltet, die auf Bedeutung [10] basieren, so hat 1/12 etwas vergleichbares komplexeres abstraktes, das auf der Wesenhaftigkeit und Komplexität selbst und dem Status [Impuls 12] [in einer Ordnung] basiert.); Software-Programmierung-Zeiger auf Container-Datenstrukturen und hier bei 1/12 die Frage, wo man diese positioniert </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> 1/14 die Analyse (größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 15 </td> <td> 1/15 Extraversion (bin mir halb sicher);mathematisch: die Schleifeninvariante, die Invariante einer Rekursion und einer Traversierung (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 22 </td> <td> Metadiversitäten könnte man das nennen: Vererbungsgrundlagen, warum wie und warum vererbt wird, z.B. Evolution oder mendelsche Regeln oder was die Programmiersprache zur Vererbung ermöglicht, oder der Teil der Wissenschaftlichen Methodik, der bewirkte, dass neuere Forschungen älterer Forschung widersprechen (weil Forschungsbaum: also Vererbung) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 24 </td> <td> Die Klärung, das Klar-machen, das Transparent machen, die Störungs-Verwaltung, das Netzwerkprotokoll (größtenteils sicher) Es ist die Invariante des Netzwerkes (24). (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 28 </td> <td> (Es ist die Invariante der Topologie) Die Frage nach der Art und Weise der Anordnung anstelle der Anordnung (d.h. der Topologie) selbst (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 30 </td> <td> Das universell abstrakt Generische Beziehungsbildende (größtenteils sicher); Die Rolle und Struktur des Universellen in der Welt, ihre Anwendung und ihr Verständnis in der Realität. Die Auswirkungen des Universellen in verschiedenen Disziplinen und die Erklärung der Phänomene der Natur durch das Universelle – Das ist das Meta-Thema des Universellen (15) und gleichzeitig ist das das konkrete Thema von dessen Meta-Thema, der Universellen Ordnung (60), und es ist das Praxis-Thema von dessen Theorie-Thema: der universellen Relation (90); 1/30: Invariantentheorie (halb sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 33 </td> <td> Automatisierungsprinzipien oder Automatisierungsgrundlagen (halb bis größtenteils sicher); regelkonforme bzw. regelerhaltende, kovariante Übersetzungs-Gestaltung, also nicht die Übersetzung selbst, sondern nach welchen Grundsätzen diese vonstatten geht (halb bis größtenteils sicher) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 36 </td> <td> Datenbankanalyse, Datenbank Rückbetrachtung, Daten, die es zu managen gilt (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 42 </td> <td> die Grundlagen des Schöpfens (Frage nach einem „Wie der Transformation“), z.B. wie und warum aus einer Klasse eine Instanz wird, wie ein Hobby zu erschaffenen Dingen führt (größtenteils sicher) </td> </tr>
# </table>

# %%
HTML(teste("u2/14-2/15"))
# Out:
# ,
# 7
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> das Gute für sich wollen, durch z.B. beliebt sein zu wollen (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_2, p4_0,3,1,6"> 2/n Galaxie </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> das Gute für sich wollen, durch z.B. beliebt sein zu wollen (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Universum,✗Grundstrukturen,✗Grundstrukturen,, p2_p3_0_Reziproke_von_Transzendentalien,p3_1_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_2_Reziprokes,p3_3_,p3_4_,p3_5_,p3_6_,p3_7_, p4_4,1"> Reziproke 1/n von „Transzendentalien bzw. Strukturalien“: Die Grundlage für Gleichförmiges-Polygon-Religionen (Reziproke sind Typ 15 und diese Strukturalien, von denen die Reziproke gebildet werden sind zudem auch Typ 15.) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> 1/7 Position (mathematisch),d.h.: „Lage, Situation, Gegebenheit“ (komplementär zu 7=Richtung selbst); „günstig-gelegen“ (komplementär zu 7=das Gute) (bin mir sehr sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Universum_n/m,, p2_p3_0_2, p4_0,4,1,6"> 2/n Universum </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> 1/7 Position (mathematisch),d.h.: „Lage, Situation, Gegebenheit“ (komplementär zu 7=Richtung selbst); „günstig-gelegen“ (komplementär zu 7=das Gute) (bin mir sehr sicher) (1/7)<br>2/14 Operanden und Operation, nicht unbedingt das Ergebnis (größtenteils sicher), 3/21 Ressourcen und Umstände (einigermaßen sicher), (1/14)/(1/2) die Bestandsaufnahme und Rekapitulation </td> </tr>
# </table>

# %%
HTML(teste("vu2/14-2/15"))

# %%
HTML(teste("a 2/3-2/4,v2/5-2/6"))
# Out:
# C
# ,
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '2/3-2/4,v2/5-2/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# 2,5,10,3,6,9
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '2/3-2/4,v2/5-2/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '1/2,1/5,1/10,1/3,1/6,1/9']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 3 </td> <td> Pragmatismus, pragmatisch sein (größtenteils sicher) (1/3), formen, wandeln (3/9) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> taugen, streben (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> einschätzen, bewerten, Klarheit oder Ethik wollen, gesellschaftliche Werte wollen (sicher) </td> </tr>
# <tr style="background-color:#000099;color:#ffff66;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 9 </td> <td> die potenziellen Mittel haben wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 10 </td> <td> Semantisch definieren (ich bin mir sehr sicher), erkennen lassen, für andere als Wahrheit gelten lassen, passende Wirklichkeit in seinem Gehirn durch Ontologie wollen (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_2, p4_0,3,1,6"> 2/n Galaxie </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 3 </td> <td> Brauchbarkeit, brauchen (2/[1/3] und 2/3) (größtenteils sicher); Zeugnis abgeben [4/(1/6)]; der Wirkstoff [6/(1/9)]; sich einer Rechtssprechungsart unterwerfen [8/(1/12)] </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> zu etwas passen wollen, passend sein wollen (2/5) (sicher); Erstellung [4/(1/10)] </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> Pragmatismus, pragmatisch sein (größtenteils sicher) (1/3), formen, wandeln (3/9) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 10 </td> <td> taugen, streben (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 12 </td> <td> einschätzen, bewerten, Klarheit oder Ethik wollen, gesellschaftliche Werte wollen (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 18 </td> <td> die potenziellen Mittel haben wollen (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 20 </td> <td> Semantisch definieren (ich bin mir sehr sicher), erkennen lassen, für andere als Wahrheit gelten lassen, passende Wirklichkeit in seinem Gehirn durch Ontologie wollen (größtenteils sicher) </td> </tr>
# </table>

# %%
HTML(teste("a 2/3-2/4,v2/5-2/6,v-2/10-2/12 1/1,2"))

# %%
HTML(teste("a 1/3-2/4,v1/5-2/6,v-1/10-2/12,-1/4-2/4"))

# %%
HTML(teste("a 3/4-5/6"))
# Out:
# C
# ,
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4-5/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# 2,1,1
# 1,1
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4-5/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '1,1,1/2,1,1/1,1,1/1']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_,p3_6_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_3, p4_0,3,1,6"> 3/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> entwickeln, sich heranbilden, herausbilden, sich bilden (sicher) (3/4), Wenn ich etwas benötigen sollte, kann damit überhaupt etwas erreichen? ([1/4]/[1/3]), Selbstkritik und respektvoll sein (6/8) und Frage nach Wucher oder Schnäppchen (6/8), Zusammenhänge real, irreal, möglich, unmöglich (9/12), Rechtmäßigkeit und Musterung (1/8)/(1/6) (ich bin mir sehr sicher); Subsidiarität (12/16); Zuständigkeit oder auch investigativ sein [(1/16)/(1/12)] </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Verwendbarkeit (3/5 und 3/[1/5]) (größtenteils sicher); das Privileg (6/10); Gegebenheit (9/15) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_4, p4_0,3,1,6"> 4/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Testen (4/5 und 4/[1/5]); Autonomie wollen (8/10) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> Brauchbarkeit, brauchen (2/[1/3] und 2/3) (größtenteils sicher); Zeugnis abgeben [4/(1/6)]; der Wirkstoff [6/(1/9)]; sich einer Rechtssprechungsart unterwerfen [8/(1/12)] </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_5, p4_0,3,1,6"> 5/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> Anstellung erhalten wollen bzw. genauer, infrage gekommen sein (5/[1/4] und 5/4) (größtenteils sicher); eine Verordnung oder Rechtsnorm, verordnen wollen (10/8) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> jemanden oder etwas begehren (5/6) </td> </tr>
# </table>

# %%
HTML(teste("a v 3/4-5/6"))

# %%
HTML(teste("a 3/4-3/6"))
# Out:
# C
# ,
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4-3/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# 2
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4-3/6', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '1/2']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_3, p4_0,3,1,6"> 3/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> entwickeln, sich heranbilden, herausbilden, sich bilden (sicher) (3/4), Wenn ich etwas benötigen sollte, kann damit überhaupt etwas erreichen? ([1/4]/[1/3]), Selbstkritik und respektvoll sein (6/8) und Frage nach Wucher oder Schnäppchen (6/8), Zusammenhänge real, irreal, möglich, unmöglich (9/12), Rechtmäßigkeit und Musterung (1/8)/(1/6) (ich bin mir sehr sicher); Subsidiarität (12/16); Zuständigkeit oder auch investigativ sein [(1/16)/(1/12)] </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Verwendbarkeit (3/5 und 3/[1/5]) (größtenteils sicher); das Privileg (6/10); Gegebenheit (9/15) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>

# %%
# funktioniert wieder nicht vollständig
HTML(teste("a e 3/4 5/6+1/1 6 u p"))
# Out:
# C
# ,
# 6
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4', '5/6+1/1', '6', 'universum', 'p', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# ,
# 6
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '3/4', '5/6+1/1', '6', 'universum', 'p', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> „Vorteil wollen“ (oder auch „Einfluss“ oder „Gewaltverfügung“ wie ein Richter) oder „nur „kein Nachteil“, statt Egoismus </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_3, p4_0,3,1,6"> 3/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> entwickeln, sich heranbilden, herausbilden, sich bilden (sicher) (3/4), Wenn ich etwas benötigen sollte, kann damit überhaupt etwas erreichen? ([1/4]/[1/3]), Selbstkritik und respektvoll sein (6/8) und Frage nach Wucher oder Schnäppchen (6/8), Zusammenhänge real, irreal, möglich, unmöglich (9/12), Rechtmäßigkeit und Musterung (1/8)/(1/6) (ich bin mir sehr sicher); Subsidiarität (12/16); Zuständigkeit oder auch investigativ sein [(1/16)/(1/12)] </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_6, p4_0,3,1,6"> 6/n Galaxie </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> ausbeuten wollen (sowohl im guten, als auch im nicht so guten Sinn, d.h. zunächst neutral) (6/5) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> Nehmen (das bringt es auf den Punkt.); (wo ich noch am Denken war:) Vorteile daraus gewinnen, angeführt zu werden; mehr Vorteile bei wenig angeführt werden (= Liberalismus), mehr Nachteile bei viel Führung und Richtung (= Bürokratie) (6/7); Selektieren [aus einem Märchen: „die guten ins Töpfchen, die schlechten ins Kröpfchen“] (12/14); Verständnis aufbringen für ggf. nicht mental nachvollziehbares (= sich zugeneigt relaten zu können pro Hingabe und Widmung oder mal Pionierarbeit in neuem Terrain zu leisten) (18/21); </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_4, p4_0,3,1,6"> 4/n Galaxie </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Testen (4/5 und 4/[1/5]); Autonomie wollen (8/10) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> Lohn generieren (4/7) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Universum,✗Universum,✗Universum,✗Grundstrukturen,✗Inkrementieren,✗Inkrementieren,, p2_p3_0_Wichtigste,p3_1_Transzendentalien,p3_2_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_3_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_4_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_5_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_6_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_7_,p3_8_,p3_9_,p3_10_,p3_11_,p3_12_,p3_13_, p4_4,0"> Transzendentalien, -alien, universelle Strukturalien, Meta-Paradigmen (15) Transzendentalien (15 oder u.a. 15) sind die menschliche Sicht der Strukturalien (ausschließlich Typ 15) (In Lebewesen ist es Bewusstsein.). </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> Wert (Zahlen ohne Information welche Zahlenart) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Universum_n/m,, p2_p3_0_3, p4_0,4,1,6"> 3/n Universum </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> Zustande-kommen, Schöpfung, Entstehung, Hervortreten, Geburt, Schaffung (sicher) (3 / 4); die Situation und Lage (3/[1/4]) (halb sicher); Stadium, Niveau (6/8) (halb bis größtenteils sicher), Plastizität und Elastizität und Bruchsicherheit [(1/4)/(1/3)] (halbwegs sicher), Mengeneinheit (Stück, Dutzend) (9/12) (müsste eigentlich stimmen) und Cluster einer Datamining-Cluster-Analyse (9/12) (gibt es auch als 9/20) (müsste eigentlich stimmen), Minimalismus [(1/8)/(1/6)] (das passt gut); Die einheitlichen Elemente (9), ggf. als Variablen, Konstanten, Einheiten, pro ihrer zugehörigen Menge (12) (9/12); Analysis-Funktions-Arten (sogenannte Charakteristische Eigenschaften von Funktionen) (12/16) (das kann passen) und Arbeitsberufsarten (12/16) (das kann passen); Zuständigkeit [(1/16)/(1/12)]; 18/24: der Knoten (18) oder die Kante (18) von einem Graphen (24) oder der Teil der GraphenTheorie, der die Beziehungen (18) der Graphen (24) untersuchen möchte (18/24) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Universum_n/m,, p2_p3_0_6, p4_0,4,1,6"> 6/n Universum </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Prozent oder Promille (6/5) (größtenteils sicher); die Mengen zugehörig zu einer Gleichheit von Mengen oder zu einem delta Extensionalitätsunterschied (12/10) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> SQL-relationales Ma

# %%
HTML(teste("a v 7/1"))
# Out:
# C
#
# 7
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', 'vielfache', '7/1', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '7']
#
# 7
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', 'vielfache', '7/1', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '7']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> Selbstlosigkeit (als Liebe oder ohne) (Wölfe, Hunde) (dein Selbst von anderen abhängig machen, anderen zu überlassen, geben) oder „friedfertige Gutmütigkeit und Positivität zu anderen“ (Kühe [Meta-Paradigma 7]), vielleicht etc. (das sind schon 3 Arten des Guten); Dazu bereit sein, Teil von Synergieeffekten zu werden </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> Lösen von echten Problemen (Ich-Losigkeit, dein Ich von anderen abhängig machen, es zu überlassen); Synergieeffekte herstellen wollen; gegenseitig gut sein und ggf. gegenseitig sich anzuführen </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 21 </td> <td> (klar auf den Punkt gebracht) Über-ich-losigkeit, Leidenschaft zu einer Aufgabe, Beruf, Hobby, zu Fortpflanzung, sein Überich durch andere Menschen definieren zu lassen (100% sicher); (größere Gefahr beraubt zu werden, als wäre man ein Egoist, da sich Egoisten aus Egoismus mehr absichern) Vermutlich ist der Grundgedanke die gegenseitige Selbstlosigkeit. </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 6 </td> <td> 28 </td> <td> (klar auf den Punkt gebracht) „Lebensratgeber sein wollen“. Eine Quelle oder Autorität in allgemeinen Lebensfragen sein wollen; Synergieeffekte verbinden können; Total im sogenannten Flow zu sein (die genannte Betrunkenheit im Thomasevangelium 28 ist das hier), aber den eigenen Flow der Tätigkeit total durch Mitmenschen zu definieren und nicht durch sich selbst, also Flow-Losigkeit. Motiv, ständig in der Durchführung zu sein, die Lebewesen in seiner Umgebung da hin zu bringen, was besser für sie ist und dann zum Wohle aller, Anführer erschaffen (um eine Topologie zu bauen) (sehr sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 7 </td> <td> 35 </td> <td> (klar auf den Punkt gebracht) philanthropisch tätig sein wollen (ggf. nicht nur auf Menschen beschränkt, sondern pro ggf. weiteren Lebewesen). Für dich gilt, was für andere gilt (größtenteils sicher) und deshalb etwa Robin Hood spielen (d.h. von Reich nach Arm umverteilen) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 42 </td> <td> (klar auf den Punkt gebracht) die intrinsische „Widmung“ als grundlegendes Motiv. Für Widmung gilt ansonsten: Intrinsisch einen hoch qualitativen Lebenspartner wollen (wie Milliardäre), wodurch man ggf. etwas aufbauen kann. (ich bin mir sicher) Die 42 ist wie ein Anführer die Richtung basierend auf Werten bestimmen und ob diese wertvoll genug sind, basierend auf ihrer Richtungsbestimmung. Das, was für dich wertvoll ist, definiert sich daraus, was für andere wertvoll ist. (=Wertüberzeugungs-Losigkeit) (ich bin mir sicher) Die Widmung (42) ist die konkret (2) gewordene Hingabe (21) (2*21=42). Hier vereinen sich grundsätzliche Gedanken des Christentums und Judentums. </td> </tr>
# <tr style="background-color:#000099;color:#ffff66;"> <td style="background-color:#000000;color:#ffffff;"> 8 </td> <td> 49 </td> <td> (klar auf den Punkt gebracht) intrinsisch verzagen, aber eigentlich nicht verzagen wollen, aber es doch tun (sich als Opfer sehen, sich nicht helfen können) (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 56 </td> <td> (klar auf den Punkt gebracht) Die gesellschaftlichen Zusammenhänge, was die eigentlichen tatsächlichen Schwierigkeiten des Volkes und dessen Einzelpersonen sind, erkennen und durchschauen wollen (größtenteils sicher bis sehr sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 9 </td> <td> 63 </td> <td> (klar auf den Punkt gebracht) „Hingebung“ (zu allem erdenklichen: Folgen einer Leidenschaft, zu einer Aufgabe, zu Personen) (Steigerung von Leidenschaft). Den guten Zweck als oberstes Ziel (für Unternehmensgründung, Hobbies, etc.) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 10 </td> <td> 70 </td> <td> (klar auf den Punkt gebracht) Probleme der Welt an der Wurzel anpacken wollen, statt mit Philanthropie an den Symptomen zu arbeiten. (für dich ist wirklich und wahr, was für andere wirklich und wahr ist) (Problemlösungen erwirken wollen) (bereit sein, sich vollkommen aufzuopfern für das richtige) (größtenteils sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#000000;color:#ffffff;"> 10 </td> <td> 77 </td> <td> (klar auf den Punkt gebracht) „Xenophilie als Absicht“. Alles das fremd ist auf dem Planeten (verschiedenstartige höhere Lebewesen und Menschen) und sich wegen fehlendem Wissen, fehlender Information, Intelligenz oder Geist voneinander entfernt ist, mit Wissen, Information, Intelligenz und Geist füllen (größtenteils sicher) Das Gute und die Richtungsweisung möglichst fremder Lebewesens annehmen und ausprobieren wollen (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 11 </td> <td> 84 </td> <td> (klar auf den Punkt gebracht) „Leitbilder für alle vorgeben wollen“ (sicher) - Etwas zustande bringen wollen, dass ersichtlich gemacht wird, welche gutwilligen Eigenschaften eine Person besitzt, in welche abstrakte Richtung eine Person geht, indem sie sich nicht offenbaren können, sondern sie offenbart bzw. „gelesen“ werden (halb sicher bis sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 11 </td> <td> 91 </td> <td> (klar auf den Punkt gebracht) „Sich für gute Lebewesen und gute Menschen aufopfern wollen“ (=Helfen+Selbstlosigkeit in einem). (größtenteils sicher) In allen Denkansätzen der gutartigen Richtungsweisung von Anführern denken. Den Guten und Anführern helfen. Den Helfern Gutes tun. Es nicht nur dabei zu belassen auf seinen Nachwuchs und seine Lebensgrundlage zu achten. In jedem beliebigen Moment die Richtung als Anführer bestimmen können, nicht nur durch Fähigkeit (2), sondern durch alle Denkansätze (13) (Das ist viel potenter!). (sicher) </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 11 </td> <td> 98 </td> <td> (klar auf den Punkt gebracht) “Insofern ein Held sein zu wol

# %%
HTML(teste("a 2/2-4/4,-3/3"))
# Out:
# C
# ,
#
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '2/2-4/4,-3/3', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# 1,2,1,-1,1
# 1,1,-1,2,1
# ['absicht', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '2/2-4/4,-3/3', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable', '1,1,-1,2,1,1,1/1,1/2,1,1/1,-1,1/-1,2,1,1/1']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> „Können“ (bzw,. „Können wollen“ 2*1) (Allein die Fähigkeit besitzen wollen [1], sich fortpflanzen zu können [2] [1*2=2]) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_,p3_6_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_2, p4_0,3,1,6"> 2/n Galaxie </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 3 </td> <td> Brauchbarkeit, brauchen (2/[1/3] und 2/3) (größtenteils sicher); Zeugnis abgeben [4/(1/6)]; der Wirkstoff [6/(1/9)]; sich einer Rechtssprechungsart unterwerfen [8/(1/12)] </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_3, p4_0,3,1,6"> 3/n Galaxie </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> Verwenden (3/2) (größtenteils sicher); griffbereit [3*(1/2)] (größtenteils sicher); investieren [6/(1/4)]; Investitionssumme bestimmen [9/(1/6)]; die Anordnung oder der Erlass [12/(1/8)] </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> entwickeln, sich heranbilden, herausbilden, sich bilden (sicher) (3/4), Wenn ich etwas benötigen sollte, kann damit überhaupt etwas erreichen? ([1/4]/[1/3]), Selbstkritik und respektvoll sein (6/8) und Frage nach Wucher oder Schnäppchen (6/8), Zusammenhänge real, irreal, möglich, unmöglich (9/12), Rechtmäßigkeit und Musterung (1/8)/(1/6) (ich bin mir sehr sicher); Subsidiarität (12/16); Zuständigkeit oder auch investigativ sein [(1/16)/(1/12)] </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_4, p4_0,3,1,6"> 4/n Galaxie </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> „Können“ (bzw,. „Können wollen“ 2*1) (Allein die Fähigkeit besitzen wollen [1], sich fortpflanzen zu können [2] [1*2=2]) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 3 </td> <td> entwickeln, etwas bilden (sicher) (4/3); Verliehen oder gestohlen oder Eigentum im Besitz (8/6) Respekt bekommen (ist hier eigentlich nur ein Aspekt) (8/6); Ordnungsmittel [12/(1/9)] </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# </table>

# %%
HTML(teste("a e 1/1-3/4,-1/2-2/3"))

# %%
HTML(teste("av1/10-1/11+0/1+1/2 1/15"))

# %%
HTML(teste("u1/1-4/4,-2/2-3/3"))

# %%
HTML(teste("uv1/1-4/4,-2/2-3/3"))
# Out:
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> „Können“ (bzw,. „Können wollen“ 2*1) (Allein die Fähigkeit besitzen wollen [1], sich fortpflanzen zu können [2] [1*2=2]) </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 3 </td> <td> ‚Nutzen‘ (altes Testament und Mensch); wahrscheinlich: „ ‚Beißen‘ als zentrales Konzept; ‚Mimese‘ und ‚Mimikry‘ (3 mit wahrscheinlich auch 2)“; Rüssel eines Elefanten und Tentakel nutzen als weitere Formen </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> betätigen (machen) bzw. durchführen; Eifer </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> „Selbstsucht“ (nicht Egoismus) oder auch „infrage kommen“ oder „Bezogenheit auf nur dich selbst, sich nur selbst sehen“ </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 6 </td> <td> „Vorteil wollen“ (oder auch „Einfluss“ oder „Gewaltverfügung“ wie ein Richter) oder „nur „kein Nachteil“, statt Egoismus </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> Selbstlosigkeit (als Liebe oder ohne) (Wölfe, Hunde) (dein Selbst von anderen abhängig machen, anderen zu überlassen, geben) oder „friedfertige Gutmütigkeit und Positivität zu anderen“ (Kühe [Meta-Paradigma 7]), vielleicht etc. (das sind schon 3 Arten des Guten); Dazu bereit sein, Teil von Synergieeffekten zu werden </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 8 </td> <td> „Selbstgerechtigkeit“ (8) oder „besitzen wollen“ (3 mit 8) </td> </tr>
# <tr style="background-color:#000099;color:#ffff66;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 9 </td> <td> „Zweck“ oder auch „sich vereinen wollen“ </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 10 </td> <td> Bedeutung [Verstand, verstehen (-10 durch 8 typisiert) (Mensch); Vernunft, rationalisieren (+10 durch 12 typisiert) (Mensch); Erkenntnis gewinnen wollen (10 durch 10 typisiert) Religion 10, Wille vieler Philosophen, Greifvogel wie Adler; Pferd (10 durch 7 typisiert)] </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 11 </td> <td> Die Identität alles Fremden annehmen und ausprobieren wollen, diese spielerisch leugnend erfassen. Dabei diese fremden Absichten aber nicht zu behalten, sondern diese nur ausprobieren und annehmen wollen. Sucht Positives zu erhalten, z.B. Hilfe; Sucht nach Fremdartigen </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 12 </td> <td> (sich) sortieren; Sachlichkeit und Ordnung herrichten wollen; die abstrakten Eigenschaften von Individuen verinnerlichen wollen; den Wesenskern herauskristalisieren wollen </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 13 </td> <td> echtes Helfen (Ich-Vollheit) (jemanden zum Überleben [3] bringen) oder extrinsisch Existenz beenden lassen, hauptsächlich wenn zur schwarzen Sonne geworden; die Denkansätze anderer Menschen; Sucht anderen Positives zu geben (weil man das fürs Helfen muss) verinnerlichen wollen </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 14 </td> <td> Lösen von echten Problemen (Ich-Losigkeit, dein Ich von anderen abhängig machen, es zu überlassen); Synergieeffekte herstellen wollen; gegenseitig gut sein und ggf. gegenseitig sich anzuführen </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 15 </td> <td> Selbstrespekt (Ich-Vollheit), nachhaltigen Nutzen generieren wollen (,aber erst mit Typ 30 können), Weltverständnis durch mentales Wiederholen von Dingen. Der Grundgedanke ist die gegenseitige Geltung (5). </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 3 </td> <td> 16 </td> <td> Genügen wollen, z.B. Anforderungen genügen, überhaupt und allgemein; vielleicht auch produktiv sein zu wollen </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 17 </td> <td> Abneigung (eine sittliche Position beibehalten) = Meinungen haben überhaupt, und da andere Meinungen haben überhaupt; Abneigung = Prozess, dass alle sich positionieren durch ihre Meinung; Sucht danach sich in Form von Gedanken zu positionieren </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 18 </td> <td> Zuneigung (sich zu anderen Menschen „relaten“ zu können), jemanden mögen wollen </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 19 </td> <td> Fan sein, andere motivieren und anspornen wollen; Sucht nach begeisterungswürdigem Extremen </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 20 </td> <td> (klar auf den Punkt gebracht) Familienliebe oder Familienrespekt oder beides und mehr, nicht zu Einzelpersonen; Heimat wollen (ich bin mir sicher) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 21 </td> <td> (klar auf den Punkt gebracht) Über-ich-losigkeit, Leidenschaft zu einer Aufgabe, Beruf, Hobby, zu Fortpflanzung, sein Überich durch andere Menschen definieren zu lassen (100% sicher); (größere Gefahr beraubt zu werden, als wäre man ein Egoist, da sich Egoisten aus Egoismus mehr absichern) Vermutlich ist der Grundgedanke die gegenseitige Selbstlosigkeit. </td> </tr>
# <tr style="background-color:#ffff66;color:#000099;"> <td style="background-color:#000000;color:#ffffff;"> 4 </td> <td> 22 </td> <td> (klar auf den Punkt gebracht) (wissenschaftlich) „forschen“. (sicher) Die Fähigkeiten alles Fremden annehmen und ausprobieren wollen, aber dann nicht unbedingt diese Fähigkeit sich anzueignen, bei der Fähigkeit zu bleiben. Intrinsisch forschen und ergründen zu wollen, Entdeckungseifer (andere und die Welt durchschauen wollen und sich selbst verändern können), intrinsisch Wissenschaftler sein w

# %%
HTML(teste("a 1/2,4,3/4-3/5,3/5-4/5 7,1/1+0/0+0/0"))
# Out:
# 2,1+0+0,
# 2,1+0+0,
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> betätigen (machen) bzw. durchführen; Eifer </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 7 </td> <td> Selbstlosigkeit (als Liebe oder ohne) (Wölfe, Hunde) (dein Selbst von anderen abhängig machen, anderen zu überlassen, geben) oder „friedfertige Gutmütigkeit und Positivität zu anderen“ (Kühe [Meta-Paradigma 7]), vielleicht etc. (das sind schon 3 Arten des Guten); Dazu bereit sein, Teil von Synergieeffekten zu werden </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_,p3_6_, p4_0,3"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# <tr style="background-color:#66ff66;color:#000000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 2 </td> <td> möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_3, p4_0,3,1,6"> 3/n Galaxie </td> </tr>
# <tr style="background-color:#9999ff;color:#202000;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 4 </td> <td> entwickeln, sich heranbilden, herausbilden, sich bilden (sicher) (3/4), Wenn ich etwas benötigen sollte, kann damit überhaupt etwas erreichen? ([1/4]/[1/3]), Selbstkritik und respektvoll sein (6/8) und Frage nach Wucher oder Schnäppchen (6/8), Zusammenhänge real, irreal, möglich, unmöglich (9/12), Rechtmäßigkeit und Musterung (1/8)/(1/6) (ich bin mir sehr sicher); Subsidiarität (12/16); Zuständigkeit oder auch investigativ sein [(1/16)/(1/12)] </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Verwendbarkeit (3/5 und 3/[1/5]) (größtenteils sicher); das Privileg (6/10); Gegebenheit (9/15) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗gebrochen-rational_Galaxie n/m,, p2_p3_0_4, p4_0,3,1,6"> 4/n Galaxie </td> </tr>
# <tr style="background-color:#009900;color:#ffffff;"> <td style="background-color:#000000;color:#ffffff;"> 2 </td> <td> 5 </td> <td> Testen (4/5 und 4/[1/5]); Autonomie wollen (8/10) </td> </tr>
# </table>

# %% [markdown]
# ## Test: ob ReTa gutes Markdown ausgibt
#
# | | |Licht (10) |
# |:--:|:--:|:--:|
# |1|1 |inneres Licht (unsicher) |
# |1|2 |äußeres Licht (unsicher) |
