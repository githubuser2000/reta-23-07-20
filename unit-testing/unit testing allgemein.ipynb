# %%
from ansi2html import Ansi2HTMLConverter
import sys
sys.path.insert(1, '/home/alex/myRepos/reta')
import subprocess
from IPython.core.display import HTML
# Erstellen Sie einen neuen Konverter mit Standardoptionen
converter = Ansi2HTMLConverter()

def externCommand(cmd: str, parameter: list[str]):
    #return subprocess.check_output([cmd, *parameter], stderr=subprocess.STDOUT, universal_newlines=True)
    p = subprocess.Popen([cmd, *parameter], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    output, err = p.communicate()
    return output

befehl = "a u e 1".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi4 { text-decoration: underline; }
# .ansi30 { color: #000316; }
# .ansi37 { color: #F5F1DE; }
# .ansi41 { background-color: #aa0000; }
# .ansi100 { background-color: #7f7f7f; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# 1
# ['absicht', 'universum', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '1']
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone,    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil              </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne</span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen</span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13)  </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">als Form des Geistes (15)                                                </span>
#  1 <span class="ansi100"></span><span class="ansi37 ansi100">„Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle    </span>
#    <span class="ansi100"></span><span class="ansi37 ansi100">Paradigmen haben: einen „Denkansatz“)                                    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Transzendentalien, -alien, universelle Strukturalien, Meta-Paradigmen    </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">(15) Transzendentalien (15 oder u.a. 15) sind die menschliche Sicht der  </span>
#    <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Strukturalien (ausschließlich Typ 15) (In Lebewesen ist es Bewusstsein.).</span>
#  1 <span class="ansi100"></span><span class="ansi37 ansi100">Identität, z.B. mathematisch (1)                                         </span>
#
# </pre>
# </body>
#
# </html>

# %%
from IPython.display import HTML
import sys
sys.path.insert(1, '/home/alex/myRepos/reta')
import subprocess
from IPython.core.display import HTML
# Erstellen Sie einen neuen Konverter mit Standardoptionen

def externCommand(cmd: str, parameter: list[str]):
    #return subprocess.check_output([cmd, *parameter], stderr=subprocess.STDOUT, universal_newlines=True)
    p = subprocess.Popen([cmd, *parameter], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    output, err = p.communicate()
    return output

befehl = "a u e 1 -spalten --breite=0 -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# 1
# ['absicht', 'universum', 'keineEinZeichenZeilenPlusKeineAusgabeWelcherBefehlEsWar', '1', '-spalten', '--breite=0', '-ausgabe', '--art=html', '--onetable']
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> </tr>
# </table>
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Universum,✗Universum,✗Universum,✗Grundstrukturen,✗Inkrementieren,✗Inkrementieren,, p2_p3_0_Wichtigste,p3_1_Transzendentalien,p3_2_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_3_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_4_Strukturalien_bzw_Meta-Paradigmen_bzw_Transzendentalien_(15),p3_5_warum_Transzendentalie_=_Strukturgroesse_=_Charakter,p3_6_warum_Transzendentalie_=_Komplexität_von_Michael_Commons,p3_7_,p3_8_,p3_9_,p3_10_, p4_4,0"> Transzendentalien, -alien, universelle Strukturalien, Meta-Paradigmen (15) Transzendentalien (15 oder u.a. 15) sind die menschliche Sicht der Strukturalien (ausschließlich Typ 15) (In Lebewesen ist es Bewusstsein.). </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> Identität, z.B. mathematisch (1) </td> </tr>
# </table>

# %%
befehl = "reta -zeilen --vorhervonausschnitt=1 -spalten --grundstrukturen=paradigmen -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# reta -zeilen --vorhervonausschnitt=1 -spalten --grundstrukturen=paradigmen -ausgabe --art=html --onetable
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# </table>

# %%
befehl = "reta -zeilen --vorhervonausschnitt=1 -spalten --breiten=50,30 --breite=70 --grundstrukturen=paradigmen -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Extrinsische (= es indirekt </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> es direkt wollen und nicht indirekt) emotionale </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> wollen und nicht direkt zu </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Intentionen bzw. Motive für Sternpolygone, </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> wollen) (ggf. rationale) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Motive für gleichförmige </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> 13, weil vermenschlicht) (Ein beliebiges Motiv zu </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Polygone, Paradigmen, </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> haben ist Typ 1) (Jedes einzelne Motiv ergibt sich </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> auch daraus, aus welchen Paradigmen und Meta- </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen der Mensch besteht, ist also immer eine </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Zusammensetzung) Absichten (13) als Form des </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Geistes (15) </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und </td> <td> die Methode des Wie; fachliche </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> alles weitere, das alle Paradigmen haben: einen </td> <td> Spezialisierung (2/2), </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> „Denkansatz“) </td> <td> wählerisch sein (3/3) (halb </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bis größtenteils sicher); Das </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> hier alles ist wahrscheinlich </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> falsch: Erschaffen, zustande </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bringen (4/4); genügen (5/5); </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> veranschlagen oder Effizienz </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td>

# %%
befehl = "reta -zeilen --vorhervonausschnitt=1 -spalten --breite=25 --breiten=50,30 --grundstrukturen=paradigmen -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# reta -zeilen --vorhervonausschnitt=1 -spalten --breite=25 --breiten=50,30 --grundstrukturen=paradigmen -ausgabe --art=html --onetable
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Extrinsische (= es indirekt </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> es direkt wollen und nicht indirekt) emotionale </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> wollen und nicht direkt zu </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intentionen bzw. Motive für Sternpolygone, </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> wollen) (ggf. rationale) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Motive für gleichförmige </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> 13, weil vermenschlicht) (Ein beliebiges Motiv zu </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Polygone, Paradigmen, </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> haben ist Typ 1) (Jedes einzelne Motiv ergibt sich </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> auch daraus, aus welchen Paradigmen und Meta- </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen der Mensch besteht, ist also immer eine </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Zusammensetzung) Absichten (13) als Form des </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Geistes (15) </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und </td> <td> die Methode des Wie; fachliche </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> alles weitere, das alle Paradigmen haben: einen </td> <td> Spezialisierung (2/2), </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> „Denkansatz“) </td> <td> wählerisch sein (3/3) (halb </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bis größtenteils sicher); Das </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> hier alles ist wahrscheinlich </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> falsch: Erschaffen, zustande </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bringen (4/4); genügen (5/5); </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="back

# %%
befehl = "reta -zeilen --vorhervonausschnitt=1 -spalten --breite=0 --breiten=50,30 --grundstrukturen=paradigmen -ausgabe --art=html --onetable".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Extrinsische (= es indirekt </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> es direkt wollen und nicht indirekt) emotionale </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> wollen und nicht direkt zu </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Intentionen bzw. Motive für Sternpolygone, </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> wollen) (ggf. rationale) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Motive für gleichförmige </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> 13, weil vermenschlicht) (Ein beliebiges Motiv zu </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Polygone, Paradigmen, </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> haben ist Typ 1) (Jedes einzelne Motiv ergibt sich </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> auch daraus, aus welchen Paradigmen und Meta- </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Paradigmen der Mensch besteht, ist also immer eine </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Zusammensetzung) Absichten (13) als Form des </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_zaehlung, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_nummerierung, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_Grundstrukturen,Menschliches,Wichtigstes_zum_verstehen, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Motive,p3_2_Wichtigste,p3_3_,p3_4_,p3_5_, p4_0,3"> Geistes (15) </td> <td class="z_0 r_3 p1_Grundstrukturen,Grundstrukturen,Menschliches, p2_p3_0_Paradigmen_sind_Absichten_(13),p3_1_Reziprokes,p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_1,3"> </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und </td> <td> die Methode des Wie; fachliche </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> alles weitere, das alle Paradigmen haben: einen </td> <td> Spezialisierung (2/2), </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> „Denkansatz“) </td> <td> wählerisch sein (3/3) (halb </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bis größtenteils sicher); Das </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> hier alles ist wahrscheinlich </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> falsch: Erschaffen, zustande </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> bringen (4/4); genügen (5/5); </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td> </td> <td> veranschlagen oder Effizienz </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> </td> <td>

# %%
befehl = "reta -zeilen --vorhervonausschnitt=1 -spalten --breite=0 --grundstrukturen=paradigmen -ausgabe --art=html".split()
htmlAusgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
# Out:
# reta -zeilen --vorhervonausschnitt=1 -spalten --breite=0 --grundstrukturen=paradigmen -ausgabe --art=html
# <table border=0 id="bigtable">
# <tr style="background-color:#ff2222;color:#002222;"> <td class="z_0 r_0 p1_✗Zählung,, p2_p3_0_, p4_" style="background-color:#ffffff;color:#000000;"> </td> <td class="z_0 r_1 p1_✗Nummerierung,, p2_p3_0_, p4_"> </td> <td class="z_0 r_2 p1_✗Wichtigstes_zum_verstehen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Wichtigste,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_0,3"> Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) </td> <td class="z_0 r_3 p1_✗Grundstrukturen,✗Grundstrukturen,✗Menschliches,, p2_p3_0_Reziprokes,p3_1_Paradigmen_sind_Absichten_(13),p3_2_Motive,p3_3_,p3_4_,p3_5_, p4_3,1"> Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) </td> </tr>
# <tr style="background-color:#555500;color:#aaaaff;"> <td style="background-color:#ffffff;color:#000000;"> 1 </td> <td> 1 </td> <td> „Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) </td> <td> die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) </td> </tr>
# </table>

# %%
from IPython.display import display, Markdown
display(Markdown('*some markdown* $\phi$'))
befehl = "reta -zeilen --vorhervonausschnitt=1-2+1 -spalten --breite=0 --grundstrukturen=paradigmen -ausgabe --art=markdown".split()
Ausgabe = externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl])

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
#Ausgabe war, richtig: 1:5,6,15,25,31,32,45,64
HTML(htmlAusgabe)
display(Markdown(Ausgabe))
# Out:
# *some markdown* $\phi$
# reta -zeilen --vorhervonausschnitt=1-2+1 -spalten --breite=0 --grundstrukturen=paradigmen -ausgabe --art=markdown
# | | |Intrinsische (nicht extrinsische) (intrinsisch = es direkt wollen und nicht indirekt) emotionale Intentionen bzw. Motive für Sternpolygone, Paradigmen (u.a. 13, Paradigmen sind nicht nur Typ 13, weil vermenschlicht) (Ein beliebiges Motiv zu haben ist Typ 1) (Jedes einzelne Motiv ergibt sich auch daraus, aus welchen Paradigmen und Meta-Paradigmen der Mensch besteht, ist also immer eine Zusammensetzung) Absichten (13) als Form des Geistes (15) |Extrinsische (= es indirekt wollen und nicht direkt zu wollen) (ggf. rationale) Motive für gleichförmige Polygone, Paradigmen, Reziproke 1/n (13 und oder 14) |
# |:--:|:--:|:--:|:--:|
# |1|1 |„Absicht“ (jegliche beliebige Absichten) (und alles weitere, das alle Paradigmen haben: einen „Denkansatz“) |die Methode des Wie; fachliche Spezialisierung (2/2), wählerisch sein (3/3) (halb bis größtenteils sicher); Das hier alles ist wahrscheinlich falsch: Erschaffen, zustande bringen (4/4); genügen (5/5); veranschlagen oder Effizienz und Effektivität (6/6); korrespondieren (7/7); Gerechtigkeit bestimmen (8/8); Zweckmäßigkeit (9/9); Tragweite bestimmen (10/10) |
# |1|2 |„Können“ (bzw,. „Können wollen“ 2*1) (Allein die Fähigkeit besitzen wollen [1], sich fortpflanzen zu können [2] [1*2=2]) |möglich, Gelegenheiten ergreifen, andere befähigen, Talent (haben wollen) (größtenteils sicher) |
# |1|3 |‚Nutzen‘ (altes Testament und Mensch); wahrscheinlich: „ ‚Beißen‘ als zentrales Konzept; ‚Mimese‘ und ‚Mimikry‘ (3 mit wahrscheinlich auch 2)“; Rüssel eines Elefanten und Tentakel nutzen als weitere Formen |Pragmatismus, pragmatisch sein (größtenteils sicher) (1/3), formen, wandeln (3/9) |

# %%
befehl = "reta -ausg".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/rp",["-befehl",*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# reta -ausg
# Der Haupt-Parameter "-ausg" existiert hier nicht als Befehl! Es ist nur möglich: -zeilen, -spalten, -kombination, -ausgabe, -debug, -h, -help
#
# </pre>
# </body>
#
# </html>

# %%
befehl = "reta -ausgab".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))

befehl = "reta -kombination --assd".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))

befehl = "reta -ausgabe --assd".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))

befehl = "reta -spalten --assd".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))

befehl = "reta -zeilen --assd".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))

befehl = "reta -kombination ---galaxie=22".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# Der Haupt-Parameter "-ausgab" existiert hier nicht als Befehl! Es ist nur möglich: -zeilen, -spalten, -kombination, -ausgabe, -debug, -h, -help
#
# </pre>
# </body>
#
# </html>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# kein Unter-Parameter--galaxie= ",, oder, "--universum=", angegeben für Hauptparameter -kombination oder einen nicht zugehörigen Parameter: --assd
#
# </pre>
# </body>
#
# </html>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# Den Neben-Parameter "--assd" gibt es hier nicht für den Hauptparameter "-ausgabe". Oder es fehlt ein = dahinter.
#
# </pre>
# </body>
#
# </html>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# Der Unter-Parameter "--assd" existiert hier nicht als Befehl für Haupt-Parameter -spalten, oder dieser Parameter braucht Werte analog wie:
# --unterParameter=Wert1
# Es ist nur möglich: --Wichtigstes_zum_verstehen, --wichtigsteverstehen, --Menschliches, --menschliches, --Planet_(10_und_oder_12), --planet, --Wichtigstes_zum_gedanklich_einordnen, --wichtigsteeinordnen, --Operationen, --operationen, --Religionen, --religionen, --religion, --Galaxie, --galaxie, --alteschriften, --kreis, --galaxien, --kreise, --Inkrementieren, --inkrementieren, --Universum, --universum, --transzendentalien, --strukturalien, --kugel, --kugeln, --ball, --baelle, --bälle, --Multiversum, --multiversum, --Größenordnung, --groessenordnung, --strukturgroesse, --strukturgroeße, --strukturgrösse, --strukturgröße, --groesse, --stufe, --organisationen, --Meta_vs_Konkret_(Universum), --universummetakonkret, --Primzahlwirkung, --primzahlwirkung, --Grundstrukturen, --grundstrukturen, --Wirtschaft, --wirtschaft, --Pro_Contra, --procontra, --dagegendafuer, --Licht, --licht, --Bedeutung, --bedeutung, --gebrochen-rational_Galaxie n/m, --gebrochen-rational_Universum_n/m, --Symbole, --symbole, --Eigenschaften_n, --eigenschaften, --eigenschaft, --konzept, --konzepte, --Eigenschaften_1/n, --konzept2, --konzepte2, --Multiplikationen, --multiplikationen, --alles, --keinenummerierung
#
# </pre>
# </body>
#
# </html>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# Den Neben-Parameter "--assd" gibt es hier nicht für den Hauptparameter "-zeilen". Oder ein = fehlt dahinter. Möglich sind: --zeit=, --zaehlung=, --vorhervonausschnitt=, --vorhervonausschnittteiler, --primzahlvielfache=, --nachtraeglichneuabzaehlung=, --nachtraeglichneuabzaehlungvielfache=, --alles, --potenzenvonzahlen=, --typ=, --vielfachevonzahlen=, --oberesmaximum=
#
# </pre>
# </body>
#
# </html>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# kein Unter-Parameter--galaxie= ",, oder, "--universum=", angegeben für Hauptparameter -kombination oder einen nicht zugehörigen Parameter: ---galaxie=22
#
# </pre>
# </body>
#
# </html>

# %%
befehl = "reta -spalten --licht=22".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
# Der Unter-Paramaeter "--licht" existiert, aber nicht mit dem Textwert "22". Stattdessen gibt keine Nebenparameter-Textwerte.
#
# </pre>
# </body>
#
# </html>

# %%
befehl = "reta -spalten --licht= --breite=17 --breiten=50".split()
html_output = converter.convert(externCommand("/home/alex/myRepos/reta/reta",[*befehl]))

# Geben Sie das HTML in einer Jupyter-Notebook-Zelle aus
from IPython.core.display import HTML
display(HTML(html_output))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <style type="text/css">
# .ansi2html-content { display: inline; white-space: pre-wrap; word-wrap: break-word; }
# .body_foreground { color: #AAAAAA; }
# .body_background { background-color: #000000; }
# .inv_foreground { color: #000000; }
# .inv_background { background-color: #AAAAAA; }
# .ansi1 { font-weight: bold; }
# .ansi4 { text-decoration: underline; }
# .ansi30 { color: #000316; }
# .ansi37 { color: #F5F1DE; }
# .ansi40 { background-color: #000316; }
# .ansi41 { background-color: #aa0000; }
# .ansi43 { background-color: #aa5500; }
# .ansi46 { background-color: #00aaaa; }
# .ansi47 { background-color: #F5F1DE; }
# .ansi100 { background-color: #7f7f7f; }
# .ansi103 { background-color: #ffff00; }
# .ansi106 { background-color: #00ffff; }
# </style>
# </head>
# <body class="body_foreground body_background" style="font-size: normal;" >
# <pre class="ansi2html-content">
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Licht  (10)                                  </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Kreativitäts- und    </span>
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">                                             </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Intelligenz-Typ      </span>
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">                                             </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">(gute Frage zu       </span>
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">                                             </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">welcher Zahl diese   </span>
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">                                             </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">Überschrift am Besten</span>
#       <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">                                             </span> <span class="ansi41"></span><span class="ansi30 ansi41"></span><span class="ansi4 ansi30 ansi41">passt)               </span>
#     1 <span class="ansi100"></span><span class="ansi37 ansi100">inneres Licht (unsicher)                     </span> <span class="ansi100"></span><span class="ansi37 ansi100">gespiegelt (unsicher)</span>
#     2 <span class="ansi103"></span><span class="ansi30 ansi103"></span><span class="ansi1 ansi30 ansi103">äußeres Licht (unsicher)                     </span> <span class="ansi103"></span><span class="ansi30 ansi103"></span><span class="ansi1 ansi30 ansi103">Ideal (unsicher)     </span>
#     3 <span class="ansi43"></span><span class="ansi30 ansi43">nahes Licht (unsicher)                       </span> <span class="ansi43"></span><span class="ansi30 ansi43">Naturgetreu          </span>
#       <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">(unsicher)           </span>
#     4 <span class="ansi106"></span><span class="ansi30 ansi106">allgegenwärtiges Licht (unsicher)            </span> <span class="ansi106"></span><span class="ansi30 ansi106">kontinuierlich (halb </span>
#       <span class="ansi47"></span><span class="ansi30 ansi47">                                             </span> <span class="ansi106"></span><span class="ansi30 ansi106">sicher)              </span>
# █   5 <span class="ansi43"></span><span class="ansi30 ansi43">Nachttisch-Licht                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">Axiome durch die     </span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">Kombination mit der  </span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">10                   </span>
# █   6 <span class="ansi47"></span><span class="ansi30 ansi47">Raumlicht                                    </span> <span class="ansi47"></span><span class="ansi30 ansi47">Abduktion durch die  </span>
# █     <span class="ansi47"></span><span class="ansi30 ansi47">                                             </span> <span class="ansi47"></span><span class="ansi30 ansi47">Kombination mit der  </span>
# █     <span class="ansi47"></span><span class="ansi30 ansi47">                                             </span> <span class="ansi47"></span><span class="ansi30 ansi47">10                   </span>
# █   7 <span class="ansi43"></span><span class="ansi30 ansi43">Laternenlicht                                </span> <span class="ansi43"></span><span class="ansi30 ansi43">Induktion durch die  </span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">Kombination mit der  </span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">10                   </span>
# █   8 <span class="ansi106"></span><span class="ansi30 ansi106">Dorflicht                                    </span> <span class="ansi106"></span><span class="ansi30 ansi106">Deduktion durch die  </span>
# █     <span class="ansi47"></span><span class="ansi30 ansi47">                                             </span> <span class="ansi106"></span><span class="ansi30 ansi106">Kombination mit der  </span>
# █     <span class="ansi47"></span><span class="ansi30 ansi47">                                             </span> <span class="ansi106"></span><span class="ansi30 ansi106">10                   </span>
# █   9 <span class="ansi46"></span><span class="ansi30 ansi46">Stadtlicht                                   </span> <span class="ansi46"></span><span class="ansi30 ansi46">Implikation durch die</span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi46"></span><span class="ansi30 ansi46">Kombination mit der  </span>
# █     <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi46"></span><span class="ansi30 ansi46">10                   </span>
#    10 <span class="ansi47"></span><span class="ansi30 ansi47">Tageslicht (der Sonne)                       </span> <span class="ansi47"></span><span class="ansi30 ansi47">Korrekt              </span>
#    11 <span class="ansi43"></span><span class="ansi30 ansi43">Nachtlicht des Mondes                        </span> <span class="ansi43"></span><span class="ansi30 ansi43">mutiert zu           </span>
#       <span class="ansi40"></span><span class="ansi37 ansi40">                                             </span> <span class="ansi43"></span><span class="ansi30 ansi43">Andersartigkeit      </span>
#    12 <span class="ansi47"></span><span class="ansi30 ansi47">Nachtlicht der Planeten                      </span> <span class="ansi47"></span><span class="ansi30 ansi47">Daten-Abstraktion    </span>
#    13 <span class="ansi43"></span><span class="ansi30 ansi43">totale Finsternis des Schwarzes Loches: Licht</span> <span class="
